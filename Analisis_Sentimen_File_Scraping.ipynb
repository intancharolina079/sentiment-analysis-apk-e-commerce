# %% [markdown]
# # **Sentiment Analysis APK E-commerce Tokopedia using LSTM and GRU**

# %% [markdown]
# # **Import Library**

# %%
# !pip install google-play-scraper

# %%
import pandas as pd
from google_play_scraper import reviews_all, Sort
import csv
from google.colab import drive

# %% [markdown]
# # **Scrapping Data Set**

# %%
scrapreview = reviews_all(
    'com.tokopedia.tkpd',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=11000
)

# %%
with open('ulasan_tokopedia.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])
    for review in scrapreview:
        writer.writerow([review['content']])

# %% [markdown]
# # **Loading Dataset**

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_tokopedia.csv', index=False)

# %%
app_reviews_df = pd.DataFrame(scrapreview)
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  796cbd9d-524c-47d3-9b28-36ccb8eb0f81  Pengguna Google
# 1  1ca4cd9e-4389-4fe9-ba1e-4903213b7dfa  Pengguna Google
# 2  be5049bf-bff4-4ca9-a644-f932c60bfdac  Pengguna Google
# 3  c0c8effc-fbb1-4795-ba1d-040a4ca73083  Pengguna Google
# 4  2e4214b1-b244-422b-b988-604b3c56cf43  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Tokped ini sebenarnya bagus, banyak promo.. ta...      3             69
# 1  Kekurangan Tokopedia bagi saya hanya pengirima...      3             43
# ...

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184500 entries, 0 to 184499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              184500 non-null  object
#  1   userName              184500 non-null  object
#  2   userImage             184500 non-null  object
#  3   content               184500 non-null  object
#  4   score                 184500 non-null  int64
#  5   thumbsUpCount         184500 non-null  int64
#  6   reviewCreatedVersion  128096 non-null  object
#  7   at                    184500 non-null  datetime64[ns]
#  8   replyContent          83132 non-null   object
#  9   repliedAt             83132 non-null   datetime64[ns]
#  10  appVersion            128096 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 15.5+ MB

# %%
clean_df = app_reviews_df.dropna()
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63912 entries, 0 to 184499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              63912 non-null  object
#  1   userName              63912 non-null  object
#  2   userImage             63912 non-null  object
#  3   content               63912 non-null  object
#  4   score                 63912 non-null  int64
#  5   thumbsUpCount         63912 non-null  int64
#  6   reviewCreatedVersion  63912 non-null  object
#  7   at                    63912 non-null  datetime64[ns]
#  8   replyContent          63912 non-null  object
#  9   repliedAt             63912 non-null  datetime64[ns]
#  10  appVersion            63912 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 5.9+ MB

# %%
clean_df = clean_df.drop_duplicates()
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63912 entries, 0 to 184499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              63912 non-null  object
#  1   userName              63912 non-null  object
#  2   userImage             63912 non-null  object
#  3   content               63912 non-null  object
#  4   score                 63912 non-null  int64
#  5   thumbsUpCount         63912 non-null  int64
#  6   reviewCreatedVersion  63912 non-null  object
#  7   at                    63912 non-null  datetime64[ns]
#  8   replyContent          63912 non-null  object
#  9   repliedAt             63912 non-null  datetime64[ns]
#  10  appVersion            63912 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 5.9+ MB

# %%
jumlah_ulasan_setelah_hapus_duplikat, jumlah_kolom_setelah_hapus_duplikat = clean_df.shape
clean_df.shape
# Out:
# (63912, 11)

# %%
clean_df
# Out:
#                                     reviewId         userName  \
# 0       796cbd9d-524c-47d3-9b28-36ccb8eb0f81  Pengguna Google
# 1       1ca4cd9e-4389-4fe9-ba1e-4903213b7dfa  Pengguna Google
# 2       be5049bf-bff4-4ca9-a644-f932c60bfdac  Pengguna Google
# 3       c0c8effc-fbb1-4795-ba1d-040a4ca73083  Pengguna Google
# 4       2e4214b1-b244-422b-b988-604b3c56cf43  Pengguna Google
# ...                                      ...              ...
# 184494  7c61576c-8b0f-4bce-81eb-f6fca0e77c8c  Pengguna Google
# 184495  277e83ff-8c64-4ac7-a8b0-b5df3bd2ade9  Pengguna Google
# 184497  33d8dcfb-38cd-4e8a-8be9-de51b5e68745  Pengguna Google
# 184498  7bc3fd56-d1d4-4f56-b9cf-4a6450c453d5  Pengguna Google
# 184499  ce27137a-6fdf-4bc2-bc88-904dcf394e58  Pengguna Google
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %% [markdown]
# # **Simpan ke Google Drive**

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ulasan_tokopedia_path = '/content/drive/MyDrive/ulasan_tokopedia.csv'
app_reviews_df.to_csv(ulasan_tokopedia_path, index=False)
